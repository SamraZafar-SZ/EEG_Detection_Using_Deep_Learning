# %%
# !pip install PyWavelets
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Conv1D, MaxPooling1D, Flatten, Bidirectional, LSTM, Dropout, BatchNormalization, Input
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import SparseCategoricalCrossentropy
from scipy.io import loadmat, savemat
from scipy.signal import butter, filtfilt
import os
from google.colab import drive
import pywt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.feature_selection import RFE
from sklearn.svm import SVC
from sklearn.metrics import classification_report, accuracy_score
# Out:
# Collecting PyWavelets
#   Downloading pywavelets-1.8.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.0 kB)
# Requirement already satisfied: numpy<3,>=1.23 in /usr/local/lib/python3.11/dist-packages (from PyWavelets) (2.0.2)
# Downloading pywavelets-1.8.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 66.1 MB/s eta 0:00:00
# Installing collected packages: PyWavelets
# Successfully installed PyWavelets-1.8.0

# %%
# Mount Google Drive
drive.mount('/content/drive')

# Define input and output folders
input_folder = "/content/drive/MyDrive/EEG Dataset"
processed_folder = os.path.join(input_folder, "Processed_CNN_BiLSTM")
model_save_folder = os.path.join(input_folder, "Models_CNN_BiLSTM")
os.makedirs(processed_folder, exist_ok=True)
os.makedirs(model_save_folder, exist_ok=True)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Band-pass filter function (0.5-70 Hz Butterworth filter)
def bandpass_filter(signal, lowcut=0.5, highcut=70.0, fs=173.61, order=5):
    nyquist = 0.5 * fs
    low = lowcut / nyquist
    high = highcut / nyquist
    b, a = butter(order, [low, high], btype='band')
    return filtfilt(b, a, signal)

# Function to extract DWT-based entropy features
def extract_dwt_entropy_features(signal, wavelet='db4', level=5):
    coeffs = pywt.wavedec(signal, wavelet, level=level)
    features = []
    for coeff in coeffs:
        features.append(np.mean(np.abs(coeff)))  # Approximate Entropy
        features.append(np.std(coeff))  # Standard Deviation
        features.append(np.sqrt(np.mean(coeff**2)))  # RMS
        features.append(np.mean(np.cumsum(coeff)))  # Hurst Exponent
    return np.array(features)

# %%
# Load and preprocess data for all folders
all_features, all_labels = [], []
folder_map = {'F': 0, 'N': 1, 'S': 2, 'Z': 3, 'O': 4}

for folder in folder_map.keys():
    folder_path = os.path.join(input_folder, folder)
    if not os.path.exists(folder_path):
        print(f"Warning: {folder_path} not found. Skipping...")
        continue

    for file in os.listdir(folder_path):
        file_path = os.path.join(folder_path, file)
        signal = np.loadtxt(file_path)

        # Apply band-pass filter
        filtered_signal = bandpass_filter(signal)

        # Normalize using Z-score
        scaler = StandardScaler()
        normalized_signal = scaler.fit_transform(filtered_signal.reshape(-1, 1)).flatten()

        # Extract features
        dwt_features = extract_dwt_entropy_features(normalized_signal)

        # Store features and labels
        all_features.append(dwt_features)
        all_labels.append(folder_map[folder])

# Convert to numpy arrays
X = np.array(all_features)
y = np.array(all_labels)

# Encode labels
label_encoder = LabelEncoder()
y = label_encoder.fit_transform(y)

# Perform SVM-RFE feature selection on the full dataset
svm = SVC(kernel='linear')
rfe = RFE(svm, n_features_to_select=12)
X_selected = rfe.fit_transform(X, y)

# Save combined processed data
save_path = os.path.join(processed_folder, "processed_combined.mat")
savemat(save_path, {"features": X_selected, "labels": y})
print(f"Processed combined EEG data saved at {save_path}")
# Out:
# Processed combined EEG data saved at /content/drive/MyDrive/EEG Dataset/Processed_CNN_BiLSTM/processed_combined.mat

# %%
# Split into training and testing
X_train, X_test, y_train, y_test = train_test_split(X_selected, y, test_size=0.2, random_state=42, stratify=y)

# Define CNN-BiLSTM model
def create_cnn_bilstm_model(input_shape, num_classes):
    model = Sequential([
        Input(shape=(input_shape, 1)),
        Conv1D(filters=64, kernel_size=3, activation='relu', padding='same'),
        BatchNormalization(),
        MaxPooling1D(pool_size=2),
        Conv1D(filters=128, kernel_size=3, activation='relu', padding='same'),
        BatchNormalization(),
        MaxPooling1D(pool_size=2),
        Conv1D(filters=256, kernel_size=3, activation='relu', padding='same'),
        BatchNormalization(),
        MaxPooling1D(pool_size=2),
        Bidirectional(LSTM(64, return_sequences=True)),
        Bidirectional(LSTM(32, return_sequences=False)),
        Flatten(),
        Dense(128, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.0001)),
        Dropout(0.3),
        Dense(num_classes, activation='softmax')
    ])

    model.compile(optimizer=Adam(learning_rate=0.001),
                  loss='sparse_categorical_crossentropy',
                  metrics=['accuracy'])
    return model

# Reshape input for CNN
X_train = X_train.reshape((X_train.shape[0], X_train.shape[1], 1))
X_test = X_test.reshape((X_test.shape[0], X_test.shape[1], 1))

# Train model
model = create_cnn_bilstm_model(input_shape=X_train.shape[1], num_classes=len(np.unique(y)))
model.summary()
# Out:
# Model: "sequential_14"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv1d
# Epoch 184/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.9652 - loss: 0.1043 - val_accuracy: 0.7700 - val_loss: 1.1241
# Epoch 185/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - accuracy: 0.9887 - loss: 0.0526 - val_accuracy: 0.8000 - val_loss: 0.9089
# Epoch 186/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.9893 - loss: 0.0360 - val_accuracy: 0.8100 - val_loss: 0.8225
# Epoch 187/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9750 - loss: 0.0840 - val_accuracy: 0.8000 - val_loss: 0.8807
# Epoch 188/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.9915 - loss: 0.0310 - val_accuracy: 0.8200 - val_loss: 1.0714
# Epoch 189/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.9877 - loss: 0.0435 - val_accuracy: 0.8200 - val_loss: 1.0159
# Epoch 190/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.9954 - loss: 0.0348 - val_accuracy: 0.8200 - val_loss: 0.9828
# Epoch 191/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.9927 - loss: 0.0256 - val_accuracy: 0.8100 - val_loss: 0.9778
# Epoch 192/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9990 - loss: 0.0155 - val_accuracy: 0.8100 - val_loss: 0.9446
# Epoch 193/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 1.0000 - loss: 0.0151 - val_accuracy: 0.8100 - val_loss: 0.9203
# Epoch 194/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.9980 - loss: 0.0172 - val_accuracy: 0.8100 - val_loss: 0.9138
# Epoch 195/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 1.0000 - loss: 0.0138 - val_accuracy: 0.8100 - val_loss: 1.0274
# Epoch 196/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.9921 - loss: 0.0340 - val_accuracy: 0.8100 - val_loss: 1.0539
# Epoch 197/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9924 - loss: 0.0217 - val_accuracy: 0.8300 - val_loss: 0.9340
# Epoch 198/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.9946 - loss: 0.0200 - val_accuracy: 0.8300 - val_loss: 0.8925
# Epoch 199/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - accuracy: 0.9952 - loss: 0.0236 - val_accuracy: 0.8300 - val_loss: 0.8881
# Epoch 200/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.9886 - loss: 0.0422 - val_accuracy: 0.8100 - val_loss: 0.9112

# %%
# Evaluate model
y_pred = np.argmax(model.predict(X_test), axis=1)
accuracy = accuracy_score(y_test, y_pred)
print(f"\nModel Accuracy: {accuracy:.4f}")
print("\nClassification Report:")
print(classification_report(y_test, y_pred))

# Save trained model
model_save_path = os.path.join(model_save_folder, "EEG_CNN_BiLSTM_Model.keras")
model.save(model_save_path)
print(f"Model trained and saved successfully at {model_save_path}")
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
#
# Model Accuracy: 0.8100
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.70      0.80      0.74        20
#            1       0.79      0.75      0.77        20
#            2       0.94      0.80      0.86        20
#            3       0.81      0.85      0.83        20
#            4       0.85      0.85      0.85        20
#
#     accuracy                           0.81       100
#    macro avg       0.82      0.81      0.81       100
# weighted avg       0.82      0.81      0.81       100
#
# Model trained and saved successfully at /content/drive/MyDrive/EEG Dataset/Models_CNN_BiLSTM/EEG_CNN_BiLSTM_Model.keras

# %%
model.fit(
    X_train, y_train,
    validation_data=(X_test, y_test),
    epochs=300,
    batch_size=64,
    verbose=1
)
# Evaluate model
y_pred = np.argmax(model.predict(X_test), axis=1)
accuracy = accuracy_score(y_test, y_pred)
print(f"\nModel Accuracy: {accuracy:.4f}")
print("\nClassification Report:")
print(classification_report(y_test, y_pred))

# Save trained model
model_save_path = os.path.join(model_save_folder, "EEG_CNN_BiLSTM_Model_3.keras")
model.save(model_save_path)
print(f"Model trained and saved successfully at {model_save_path}")
# Out:
# Epoch 1/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 106ms/step - accuracy: 1.0000 - loss: 0.0065 - val_accuracy: 0.7900 - val_loss: 1.0349
# Epoch 2/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 89ms/step - accuracy: 0.9957 - loss: 0.0154 - val_accuracy: 0.7700 - val_loss: 0.9747
# Epoch 3/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 72ms/step - accuracy: 1.0000 - loss: 0.0083 - val_accuracy: 0.7900 - val_loss: 0.8808
# Epoch 4/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 1.0000 - loss: 0.0086 - val_accuracy: 0.8400 - val_loss: 0.7526
# Epoch 5/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 1.0000 - loss: 0.0056 - val_accuracy: 0.8500 - val_loss: 0.7184
# Epoch 6/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 1.0000 - loss: 0.0059 - val_accuracy: 0.8500 - val_loss: 0.7143
# Epoch 7/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 1.0000 - loss: 0.0056 - val_accuracy: 0.8600 - val_loss: 0.7197
# Epoch 8/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 1.0000 - loss: 0.0063 - val_accuracy: 0.8600 - val_loss: 0.7132
# Epoch 9/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 1.0000 - loss: 0.0057 - val_accuracy: 0.8600 - val_loss: 0.6985
# Epoch 10/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9977 - loss: 0.0114 - val_accuracy: 0.8200 - val_loss: 0.8489
# Epoch 11/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.9975 - loss: 0.0089 - val_accuracy: 0.8000 - val_loss: 0.9171
# Epoch 12/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9975 - loss: 0.0101 - val_accuracy: 0.8100 - val_loss: 0.8328
# Epoch 13/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 1.0000 - loss: 0.0060 - val_accuracy: 0.8300 - val_loss: 0.7591
# Epoch 14/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 1.0000 - loss: 0.0059 - val_accuracy: 0.8400 - val_loss: 0.7288
# Epoch 15/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 1.0000 - loss: 0.0055 - val_accuracy: 0.
# Epoch 290/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.9952 - loss: 0.0168 - val_accuracy: 0.8400 - val_loss: 0.9747
# Epoch 291/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9912 - loss: 0.0449 - val_accuracy: 0.8000 - val_loss: 0.9835
# Epoch 292/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.9745 - loss: 0.0558 - val_accuracy: 0.8100 - val_loss: 1.0788
# Epoch 293/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9922 - loss: 0.0198 - val_accuracy: 0.8000 - val_loss: 0.9838
# Epoch 294/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.9898 - loss: 0.0325 - val_accuracy: 0.8000 - val_loss: 0.9561
# Epoch 295/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.9892 - loss: 0.0468 - val_accuracy: 0.8200 - val_loss: 0.9914
# Epoch 296/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 1.0000 - loss: 0.0092 - val_accuracy: 0.8200 - val_loss: 0.9857
# Epoch 297/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.9966 - loss: 0.0129 - val_accuracy: 0.8200 - val_loss: 0.9097
# Epoch 298/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 1.0000 - loss: 0.0095 - val_accuracy: 0.8000 - val_loss: 0.9715
# Epoch 299/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.9980 - loss: 0.0098 - val_accuracy: 0.7900 - val_loss: 0.8998
# Epoch 300/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - accuracy: 0.9982 - loss: 0.0078 - val_accuracy: 0.8400 - val_loss: 0.8105
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
#
# Model Accuracy: 0.8400
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.74      0.85      0.79        20
#            1       0.83      0.75      0.79        20
#            2       0.94      0.85      0.89        20
#            3       0.85      0.85      0.85        20
#            4       0.86      0.90      0.88        20
#
#     accuracy                           0.84       100
#    macro avg       0.84      0.84      0.84       100
# weighted avg       0.84      0.84      0.84       100
#
# Model trained and saved successfully at /content/drive/MyDrive/EEG Dataset/Models_CNN_BiLSTM/EEG_CNN_BiLSTM_Model_3.keras

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Conv1D, MaxPooling1D, Flatten, Bidirectional, LSTM, Dropout, BatchNormalization, Input
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import SparseCategoricalCrossentropy
from scipy.io import savemat
from scipy.signal import butter, filtfilt
import os
from google.colab import drive
import pywt
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.feature_selection import RFE
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split
from sklearn.utils.class_weight import compute_class_weight
from sklearn.metrics import classification_report, accuracy_score


# Band-pass filter function (0.5-70 Hz Butterworth filter)
def bandpass_filter(signal, lowcut=0.5, highcut=70.0, fs=173.61, order=5):
    nyquist = 0.5 * fs
    low = lowcut / nyquist
    high = highcut / nyquist
    b, a = butter(order, [low, high], btype='band')
    return filtfilt(b, a, signal)

# Function to extract DWT-based entropy features
def extract_dwt_entropy_features(signal, wavelet='db4', level=5):
    coeffs = pywt.wavedec(signal, wavelet, level=level)
    features = []
    for coeff in coeffs:
        features.append(np.mean(np.abs(coeff)))  # Approximate Entropy
        features.append(np.std(coeff))  # Standard Deviation
        features.append(np.sqrt(np.mean(coeff**2)))  # RMS
        features.append(np.mean(np.cumsum(coeff)))  # Hurst Exponent
    return np.array(features)

# Load and preprocess data for all folders
all_features, all_labels = [], []
folder_map = {'F': 0, 'N': 1, 'S': 2, 'Z': 3, 'O': 4}

for folder in folder_map.keys():
    folder_path = os.path.join(input_folder, folder)
    if not os.path.exists(folder_path):
        print(f"Warning: {folder_path} not found. Skipping...")
        continue

    for file in os.listdir(folder_path):
        file_path = os.path.join(folder_path, file)
        signal = np.loadtxt(file_path)

        # Apply band-pass filter
        filtered_signal = bandpass_filter(signal)

        # Normalize using Z-score
        scaler = StandardScaler()
        normalized_signal = scaler.fit_transform(filtered_signal.reshape(-1, 1)).flatten()

        # Extract features
        dwt_features = extract_dwt_entropy_features(normalized_signal)

        # Store features and labels
        all_features.append(dwt_features)
        all_labels.append(folder_map[folder])

# Convert to numpy arrays
X = np.array(all_features)
y = np.array(all_labels)

# Encode labels
label_encoder = LabelEncoder()
y = label_encoder.fit_transform(y)

# Perform SVM-RFE feature selection on the full dataset
svm = SVC(kernel='linear')
rfe = RFE(svm, n_features_to_select=20)  # Increased features from 12 to 20
X_selected = rfe.fit_transform(X, y)

# Save combined processed data
save_path = os.path.join(processed_folder, "processed_combined.mat")
savemat(save_path, {"features": X_selected, "labels": y})
print(f"Processed combined EEG data saved at {save_path}")

# Split into training and testing
X_train, X_test, y_train, y_test = train_test_split(X_selected, y, test_size=0.2, random_state=42, stratify=y)

# Compute class weights for imbalanced data
class_weights = compute_class_weight('balanced', classes=np.unique(y_train), y=y_train)
class_weight_dict = {i: class_weights[i] for i in range(len(class_weights))}

# Define CNN-BiLSTM model
def create_cnn_bilstm_model(input_shape, num_classes):
    model = Sequential([
        Input(shape=(input_shape, 1)),
        Conv1D(filters=64, kernel_size=3, activation='relu', padding='same'),
        BatchNormalization(),
        MaxPooling1D(pool_size=2),
        Conv1D(filters=128, kernel_size=3, activation='relu', padding='same'),
        BatchNormalization(),
        MaxPooling1D(pool_size=2),
        Conv1D(filters=256, kernel_size=3, activation='relu', padding='same'),
        BatchNormalization(),
        MaxPooling1D(pool_size=2),
        Bidirectional(LSTM(128, return_sequences=True)),
        Bidirectional(LSTM(64, return_sequences=False)),
        Flatten(),
        Dense(128, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.0001)),
        Dropout(0.3),
        Dense(num_classes, activation='softmax')
    ])

    model.compile(optimizer=Adam(learning_rate=0.0005),
                  loss='sparse_categorical_crossentropy',
                  metrics=['accuracy'])
    return model

# Reshape input for CNN
X_train = X_train.reshape((X_train.shape[0], X_train.shape[1], 1))
X_test = X_test.reshape((X_test.shape[0], X_test.shape[1], 1))

# Train model
model = create_cnn_bilstm_model(input_shape=X_train.shape[1], num_classes=len(np.unique(y)))
model.summary()

model.fit(
    X_train, y_train,
    validation_data=(X_test, y_test),
    epochs=200,
    batch_size=64,
    class_weight=class_weight_dict,
    verbose=1
)
# Out:
# Processed combined EEG data saved at /content/drive/MyDrive/EEG Dataset/Processed_CNN_BiLSTM/processed_combined.mat
# Model: "sequential_10"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv1d_27 (Conv1D)                   │ (None, 20, 64)              │             256 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_12               │ (None, 20, 64)              │             256 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling1d_25 (MaxPooling1D)      │ (None, 10, 64)              │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv1d_28 (Conv1D)                   │ (None, 10, 128)             │          24,704 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_13               │ (None, 10, 128)             │             512 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling1d_26 (MaxPooling1D)      │ (None, 5, 128)              │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv1d_29 (Conv1D)                   │ (None, 5, 256)              │          98,560 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_14               │ (None, 5, 256)              │           1,024 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling1d_27 (MaxPooling1D)      │ (None, 2, 256)              │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ bidirectional_14 (Bidirectional)     │ (None, 2, 256)              │         394,240 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ bidirectional_15 (Bidirectional)     │ (None, 128)                 │         164,352 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten_10 (Flatten)                 │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_20 (Dense)                     │ (None, 128)                 │          16,512 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_10 (Dropout)                 │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_21 (Dense)                     │ (None, 5)                   │             645 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 701,061 (2.67 MB)
#  Trainable params: 700,165 (2.67 MB)
#  Non-trainable params: 896 (3.50 KB)
# Epoch 1/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 16s 194ms/step - accuracy: 0.4190 - loss: 1.5445 - val_accuracy: 0.3400 - val_loss: 1.6150
# Epoch 2/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.6556 - loss: 1.1961 - val_accuracy: 0.3200 - val_loss: 1.6031
# Epoch 3/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.6988 - loss: 0.8942 - val_accuracy: 0.2000 - val_loss: 1.5913
# Epoch 4/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - accuracy: 0.7404 - loss: 0.6671 - val_accuracy: 0.2400 - val_loss: 1.5906
# Epoch 5/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.7724 - loss: 0.5324 - val_accuracy: 0.4200 - val_loss: 1.5988
# Epoch 6/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.7808 - loss: 0.4804 - val_accuracy: 0.3100 - val_loss: 1.5990
# Epoch 7/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.7925 - loss: 0.5072 - val_accuracy: 0.2400 - val_loss: 1.6054
# Epoch 8/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.8130 - loss: 0.4469 - val_accuracy: 0.3000 - val_loss: 1.6066
# Epoch 9/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - accuracy: 0.7730 - loss: 0.4346 - val_accuracy: 0.2700 - val_loss: 1.6016
# Epoch 10/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - accuracy: 0.8044 - loss: 0.4441 - val_accuracy: 0.3000 - val_loss: 1.6121
# Epoch 11/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - accuracy: 0.8374 - loss: 0.3795 - val_accuracy: 0.2900 - val_loss: 1.6207
# Epoch 12/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.8335 - loss: 0.3817 - val_accuracy: 0.2600 - val_loss: 1.6409
# Epoch 13/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.8304 - loss: 0.3597 - val_accuracy: 0.2600 - val_loss: 1.6532
# Epoch 14/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - accuracy: 0.8073 - loss: 0.3466 - val_accuracy: 0.2600 - val_loss: 1.6915
# Epoch 15/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.8450 - loss: 0.3551 - val_accuracy: 0.3100 - val_loss: 1.6914
# Epoch 16/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.8778 - loss: 0.2804 - val_accuracy: 0.3500 - val_loss: 1.7345
# Epoch 17/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.8871 - loss: 0.2723 - val_accuracy: 0.3500 - val_loss: 1.7335
# Epoch 18/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 83ms/step - accuracy: 0.8843 - loss: 0.2963 - val_accuracy: 0.3200 - val_loss: 1.8088
# Epoch 19/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 81ms/step - accuracy: 0.8936 - loss: 0.2490 - val_accuracy: 0.3000 - val_loss: 1.8454
# Epoch 20/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 81ms/step - accuracy: 0.
# Epoch 172/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.9844 - loss: 0.0406 - val_accuracy: 0.7800 - val_loss: 0.9829
# Epoch 173/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.9948 - loss: 0.0353 - val_accuracy: 0.7900 - val_loss: 1.0038
# Epoch 174/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.9946 - loss: 0.0339 - val_accuracy: 0.7800 - val_loss: 1.0674
# Epoch 175/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - accuracy: 1.0000 - loss: 0.0227 - val_accuracy: 0.7900 - val_loss: 1.0917
# Epoch 176/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - accuracy: 0.9920 - loss: 0.0324 - val_accuracy: 0.7700 - val_loss: 1.1058
# Epoch 177/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 60ms/step - accuracy: 0.9845 - loss: 0.0463 - val_accuracy: 0.7600 - val_loss: 1.0921
# Epoch 178/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.9804 - loss: 0.0682 - val_accuracy: 0.7300 - val_loss: 1.1984
# Epoch 179/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.9964 - loss: 0.0284 - val_accuracy: 0.7200 - val_loss: 1.3547
# Epoch 180/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - accuracy: 0.9835 - loss: 0.0471 - val_accuracy: 0.7800 - val_loss: 1.0986
# Epoch 181/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.9912 - loss: 0.0321 - val_accuracy: 0.8000 - val_loss: 1.0268
# Epoch 182/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - accuracy: 0.9934 - loss: 0.0337 - val_accuracy: 0.7800 - val_loss: 1.0551
# Epoch 183/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.9872 - loss: 0.0412 - val_accuracy: 0.8000 - val_loss: 0.9692
# Epoch 184/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - accuracy: 0.9861 - loss: 0.0740 - val_accuracy: 0.7900 - val_loss: 0.9987
# Epoch 185/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - accuracy: 0.9854 - loss: 0.0894 - val_accuracy: 0.7300 - val_loss: 1.0110
# Epoch 186/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - accuracy: 0.9726 - loss: 0.0916 - val_accuracy: 0.7500 - val_loss: 0.9677
# Epoch 187/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - accuracy: 0.9692 - loss: 0.1033 - val_accuracy: 0.7900 - val_loss: 0.9765
# Epoch 188/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - accuracy: 0.9674 - loss: 0.1113 - val_accuracy: 0.7800 - val_loss: 0.9568
# Epoch 189/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.9809 - loss: 0.0574 - val_accuracy: 0.7800 - val_loss: 0.9937
# Epoch 190/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 87ms/step - accuracy: 0.9964 - loss: 0.0317 - val_accuracy: 0.7700 - val_loss: 1.0691
# Epoch 191/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 80ms/step - accuracy: 0.9805 - loss: 0.0576 - val_accuracy: 0.8100 - val_loss: 0.9326
# Epoch 192/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 88ms/step - accuracy: 0.9864 - loss: 0.0369 - val_accuracy: 0.8000 - val_loss: 1.0000
# Epoch 193/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 99ms/step - accuracy: 1.0000 - loss: 0.0219 - val_accuracy: 0.7900 - val_loss: 1.0458
# Epoch 194/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - accuracy: 0.9901 - loss: 0.0516 - val_accuracy: 0.8100 - val_loss: 1.0057
# Epoch 195/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.9965 - loss: 0.0281 - val_accuracy: 0.8200 - val_loss: 0.9525
# Epoch 196/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - accuracy: 0.9977 - loss: 0.0209 - val_accuracy: 0.8000 - val_loss: 1.0161
# Epoch 197/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - accuracy: 0.9940 - loss: 0.0292 - val_accuracy: 0.7800 - val_loss: 1.0591
# Epoch 198/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.9959 - loss: 0.0272 - val_accuracy: 0.8000 - val_loss: 1.0587
# Epoch 199/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - accuracy: 0.9823 - loss: 0.0407 - val_accuracy: 0.7700 - val_loss: 1.0487
# Epoch 200/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.9957 - loss: 0.0336 - val_accuracy: 0.8000 - val_loss: 1.0214

# %%
# Evaluate model
y_pred = np.argmax(model.predict(X_test), axis=1)
accuracy = accuracy_score(y_test, y_pred)
print(f"\nModel Accuracy: {accuracy:.4f}")
print("\nClassification Report:")
print(classification_report(y_test, y_pred))

# Save trained model
model_save_path = os.path.join(model_save_folder, "EEG_CNN_BiLSTM_Model_2.keras")
model.save(model_save_path)
print(f"Model trained and saved successfully at {model_save_path}")
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 690ms/step
#
# Model Accuracy: 0.8000
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.67      0.60      0.63        20
#            1       0.80      0.80      0.80        20
#            2       0.80      0.80      0.80        20
#            3       0.89      0.80      0.84        20
#            4       0.83      1.00      0.91        20
#
#     accuracy                           0.80       100
#    macro avg       0.80      0.80      0.80       100
# weighted avg       0.80      0.80      0.80       100
#
# Model trained and saved successfully at /content/drive/MyDrive/EEG Dataset/Models_CNN_BiLSTM/EEG_CNN_BiLSTM_Model_2.keras
